# %%
import pandas as pd
import numpy as np
import os 
import json
import pprint
# %matplotlib inline
import tweepy
import matplotlib.pyplot as plt
from pylab import rcParams
import networkx as nx

# %%
#Twitter API credentials
consumer_key = "cvoM8D7hXXxlvBXTM8aH9X2ec"
consumer_secret = "Uk2UvH0FJY7KaDzkXYLfgiYkA1OuCwbLlGFPyodB5wcQ5bsItN"
access_token = "3303466053-xlp70tpI3X1h5ZwFMihwaxtBwv15OzzOfjhASRp"
access_secret = "F1FPJObejC4XifZWW2zri9nvi34uTtvSWIe2oIyosBw5I"
bearer_token = "AAAAAAAAAAAAAAAAAAAAAHsVJQEAAAAAF1NdDcGaVilmYsxLtSG9kzYp9Ck%3DSORNu8KqrAvrUWG0lDBaKqbyZ8DZEZyVhTzyLxEszYn2uCd1pE"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
if(api.verify_credentials):
    print ('Authentication completed successfully!')
# Out:
# Authentication completed successfully!

# %%
data_folder = "data"

def serialize_json(folder, filename, data):
    if not os.path.exists(folder):
        os.makedirs(folder, exist_ok=True)
    with open(f"{folder}/{filename}", 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
        f.close()
    print(f"Data serialized to path: {folder}/{filename}")

def read_json(path):
    if os.path.exists(path):
        with open(path, "r", encoding="utf8") as file:
            data = json.load(file)
        print(f"Data read from path: {path}")
        return data
    else:
        print(f"No data found at path: {path}")
        return {}

# %%
accounts = ["mizzaro","damiano10","Miccighel_","eglu81","KevinRoitero"]
test ="mizzaro"
#test_followers=api.followers(
#    screen_name=test
#)
#test_following=api.friends(
#    screen_name=test
#)

#print(test_followers)
# Out:
# [User(_api=<tweepy.api.API object at 0x0000010E7DC29EB0>, _json={'id': 257691637, 'id_str': '257691637', 'name': 'Dung Doan', 'screen_name': 'dungdx34', 'location': 'Hanoi University of Technology', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 120, 'friends_count': 3856, 'listed_count': 0, 'created_at': 'Fri Feb 25 23:56:08 +0000 2011', 'favourites_count': 72, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1, 'lang': None, 'status': {'created_at': 'Tue Sep 01 11:01:55 +0000 2020', 'id': 1300750731486490625, 'id_str': '1300750731486490625', 'text': 'RT @feamster: I just published "Do You Need a Ph.D.?" https://t.co/Wq1Dkp0BFN', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'feamster', 'name': 'Nick Feamster', 'id': 6222842, 'id_str': '6222842', 'indices': [3, 12]}], 'urls': [{'url': 'https://t.co/Wq1Dkp0BFN', 'expanded_url': 'https://link.medium.com/aPmBMZ6To9', 'display_url': 'link.medium.com/aPmBMZ6To9', 'indices': [54, 77]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Aug 31 14:04:44 +0000 2020', 'id': 1300434351574913026, 'id_str': '1300434351574913026', 'text': 'I just published "Do You Need a Ph.D.?" https://t.co/Wq1Dkp0BFN', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Wq1Dkp0BFN', 'expanded_url': 'https://link.medium.com/aPmBMZ6To9', 'display_url': 'link.medium.com/aPmBMZ6To9', 'indices': [40, 63]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 68, 'favorite_count': 205, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 68, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0099B9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3660852329/fdf5266b63b7dc6241b66c0ad55af055_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3660852329/fdf5266b63b7dc6241b66c0ad55af055_normal.jpeg', 'profile_link_color': '0099B9', 'profile_sidebar_border_color': '5ED4DC', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=257691637, id_str='257691637', name='Dung Doan', screen_name='dungdx34', location='Hanoi University of Technology', description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=120, friends_count=3856, listed_count=0, created_at=datetime.datetime(2011, 2, 25, 23, 56, 8), favourites_count=72, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=1, lang=None, status=Status(_ap ...
